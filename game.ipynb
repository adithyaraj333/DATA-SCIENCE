# %% [markdown]
# <a href="https://colab.research.google.com/github/adithyaraj333/DATA-SCIENCE/blob/main/game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("guessing the number between 1-100")

secret_number=36
for i in range(0,8):
    user_input=int(input("enter your guess"))
    if user_input<1 or user_input>100:

       print("invalid number ! please enter the number between1-100")
    elif user_input<secret_number:
       print("your number is lesser")
    elif user_input>secret_number:
       print("your number is higher")

    else:
      print("your guess is correct")
      print("congratulations you have guessed the number(secret_number)is[1]attempts")
      break
# Out:
# guessing the number between 1-100
# enter your guess1000
# invalid number ! please enter the number between1-100
# enter your guess20
# your number is lesser
# enter your guess30
# your number is lesser
# enter your guess36
# your guess is correct
# congratulations you have guessed the number(secret_number)is[1]attempts
